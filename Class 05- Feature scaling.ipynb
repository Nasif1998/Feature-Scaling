# %%
import pandas as pd

# %%
df = pd.read_csv('supershops.csv - supershops.csv.csv')

# %%
df
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x = df.drop('Profit', axis =1)

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
y = df['Profit']

# %%
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()

# %%
df_ad = std.fit(df[['Administration']])

# %%
df_ad
# Out:
# StandardScaler()

# %%
df.Administration = std.transform(df[['Administration']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61        0.560753  471784.10    Dhaka  192261.83
# 1        162597.70        1.082807  443898.53      Ctg  191792.06
# 2        153441.51       -0.728257  407934.54  Rangpur  191050.39
# 3        144372.41       -0.096365  383199.62    Dhaka  182901.99
# 4        142107.34       -1.079919  366168.42  Rangpur  166187.94

# %%
df.Transport = std.fit_transform(df[['Transport']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61        0.560753   2.165287    Dhaka  192261.83
# 1        162597.70        1.082807   1.929843      Ctg  191792.06
# 2        153441.51       -0.728257   1.626191  Rangpur  191050.39
# 3        144372.41       -0.096365   1.417348    Dhaka  182901.99
# 4        142107.34       -1.079919   1.273550  Rangpur  166187.94

# %% [markdown]
# # for loop

# %%
for column in x:
    if x[column].dtypes == 'int64' or x[column].dtypes == 'float64':
        x[column] = std.fit_transform(x[[column]])

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.897913        0.560753   2.165287    Dhaka
# 1         1.955860        1.082807   1.929843      Ctg
# 2         1.754364       -0.728257   1.626191  Rangpur
# 3         1.554784       -0.096365   1.417348    Dhaka
# 4         1.504937       -1.079919   1.273550  Rangpur

# %% [markdown]
# # MinMax scaler

# %%
df1 = pd.read_csv('supershops.csv - supershops.csv.csv')
df1
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
a = df1.drop('Profit', axis=1)

# %%
a.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max = MinMaxScaler()

# %%
df1['Transport'] = min_max.fit_transform(df1[['Transport']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80   1.000000    Dhaka  192261.83
# 1        162597.70       151377.59   0.940893      Ctg  191792.06
# 2        153441.51       101145.55   0.864664  Rangpur  191050.39
# 3        144372.41       118671.85   0.812235    Dhaka  182901.99
# 4        142107.34        91391.77   0.776136  Rangpur  166187.94

# %%
for column in a:
    if a[column].dtypes == 'int64' or a[column].dtypes == 'float64':
        a[column] = min_max.fit_transform(a[[column]])

# %%
a.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.651744   1.000000    Dhaka
# 1         0.983359        0.761972   0.940893      Ctg
# 2         0.927985        0.379579   0.864664  Rangpur
# 3         0.873136        0.512998   0.812235    Dhaka
# 4         0.859438        0.305328   0.776136  Rangpur

# %% [markdown]
# # MaxAbs scaler

# %%
df2 = pd.read_csv('supershops.csv - supershops.csv.csv')
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
max_abs = MaxAbsScaler()

# %%
b = df2.drop('Profit', axis=1)

# %%
df2['Transport'] = max_abs.fit_transform(df2[['Transport']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80   1.000000    Dhaka  192261.83
# 1        162597.70       151377.59   0.940893      Ctg  191792.06
# 2        153441.51       101145.55   0.864664  Rangpur  191050.39
# 3        144372.41       118671.85   0.812235    Dhaka  182901.99
# 4        142107.34        91391.77   0.776136  Rangpur  166187.94

# %%
for column in b:
    if b[column].dtypes == 'int64' or b[column].dtypes == 'float64':
        b[column] = max_abs.fit_transform(b[[column]])

# %%
b.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.692617        0.749527   1.000000    Dhaka
# 1         0.983359        0.828805   0.940893      Ctg
# 2         0.927985        0.553781   0.864664  Rangpur
# 3         0.873136        0.649738   0.812235    Dhaka
# 4         0.859438        0.500378   0.776136  Rangpur

# %% [markdown]
# # Robust scaler

# %%
df3 = pd.read_csv('supershops.csv - supershops.csv.csv')

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
c = df3.drop('Profit', axis =1)

# %%
c.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %%
from sklearn.preprocessing import RobustScaler

# %%
robust = RobustScaler()

# %%
df3['Administration'] = robust.fit_transform(df3[['Administration']])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  \
# 0        114523.61        0.345355  471784.10    Dhaka  192261.83
# 1        162597.70        0.697565  443898.53      Ctg  191792.06
# 2        153441.51       -0.524290  407934.54  Rangpur  191050.39
# 3        144372.41       -0.097977  383199.62    Dhaka  182901.99
# 4        142107.34       -0.761543  366168.42  Rangpur  166187.94
#
#    Admisintration
# 0        0.345355
# 1        0.697565
# 2       -0.524290
# 3       -0.097977
# 4       -0.761543

# %%
df3 = df3.drop('Admisintration', axis =1)

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61        0.345355  471784.10    Dhaka  192261.83
# 1        162597.70        0.697565  443898.53      Ctg  191792.06
# 2        153441.51       -0.524290  407934.54  Rangpur  191050.39
# 3        144372.41       -0.097977  383199.62    Dhaka  182901.99
# 4        142107.34       -0.761543  366168.42  Rangpur  166187.94

# %%
for column in c:
    if c[column].dtypes == 'int64' or c[column].dtypes == 'float64':
        c[column] = robust.fit_transform(c[[column]])

# %%
c.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0         0.672530        0.345355   1.552016    Dhaka
# 1         1.452113        0.697565   1.383714      Ctg
# 2         1.303634       -0.524290   1.166654  Rangpur
# 3         1.156567       -0.097977   1.017368    Dhaka
# 4         1.119836       -0.761543   0.914576  Rangpur
